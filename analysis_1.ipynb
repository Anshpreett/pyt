# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.read_excel('sample.xlsx')
# Out:
#    id first name last name  basic salar  d.a  hr..a  t.a department  fine
# 0   1        Ram    Sharma        30000  0.4    0.8  0.1      sales   600
# 1   2      Vijay    Pandey        25000  0.3    0.8  0.1   purchase   299
# 2   3      Imran      Aali        45000  0.5    0.8  0.1        rnd   588
# 3   4       Ajay    Pandey        25000  0.5    0.8  0.1      sales  1020
# 4   5      Vijay    Sharma        19500  0.4    0.6  0.1   purchase   399
# 5   6      Rohan    Kapoor        50000  0.5    0.8  0.1        rnd     0
# 6   7     Vidhya     Singh        52000  0.5    0.8  0.1      sales     0
# 7   8      Suraj     Singh        95000  0.4    1.0  0.5   purchase   299
# 8   9      Arjun    Kapoor        10000  0.4    0.6  0.1        rnd   299
# 9  10    Arun Kr    Pandey        30000  0.5    0.8  0.1      sales   299

# %%
data = pd.read_excel('sample.xlsx')
data.head()
# Out:
#    id first name last name  basic salar  d.a  hr..a  t.a department  fine
# 0   1        Ram    Sharma        30000  0.4    0.8  0.1      sales   600
# 1   2      Vijay    Pandey        25000  0.3    0.8  0.1   purchase   299
# 2   3      Imran      Aali        45000  0.5    0.8  0.1        rnd   588
# 3   4       Ajay    Pandey        25000  0.5    0.8  0.1      sales  1020
# 4   5      Vijay    Sharma        19500  0.4    0.6  0.1   purchase   399

# %%
data.tail()
# Out:
#    id first name last name  basic salar  d.a  hr..a  t.a department  fine
# 5   6      Rohan    Kapoor        50000  0.5    0.8  0.1        rnd     0
# 6   7     Vidhya     Singh        52000  0.5    0.8  0.1      sales     0
# 7   8      Suraj     Singh        95000  0.4    1.0  0.5   purchase   299
# 8   9      Arjun    Kapoor        10000  0.4    0.6  0.1        rnd   299
# 9  10    Arun Kr    Pandey        30000  0.5    0.8  0.1      sales   299

# %%
data['first name']
# Out:
# 0        Ram
# 1      Vijay
# 2      Imran
# 3       Ajay
# 4      Vijay
# 5      Rohan
# 6     Vidhya
# 7      Suraj
# 8      Arjun
# 9    Arun Kr
# Name: first name, dtype: object

# %%
data['basic salar'].mean()
# Out:
# 38150.0

# %%
data.columns.to_list()
# Out:
# ['id',
#  'first name',
#  'last name',
#  'basic salar',
#  'd.a',
#  'hr..a',
#  't.a',
#  'department',
#  'fine']

# %%
data[['first name','basic salar','fine']]
# Out:
#   first name  basic salar  fine
# 0        Ram        30000   600
# 1      Vijay        25000   299
# 2      Imran        45000   588
# 3       Ajay        25000  1020
# 4      Vijay        19500   399
# 5      Rohan        50000     0
# 6     Vidhya        52000     0
# 7      Suraj        95000   299
# 8      Arjun        10000   299
# 9    Arun Kr        30000   299

# %%
data.set_index('id', inplace=True)

# %%
data['basic salar'].plot(kind='bar')
# Out:
# <Axes: xlabel='id'>

# %%
data['basic salar'].plot.bar()
# Out:
# <Axes: xlabel='id'>

# %%
data['basic salar'].plot()
# Out:
# <Axes: xlabel='id'>

# %%
data['basic salar'].plot.area()
# Out:
# <Axes: xlabel='id'>

# %%
data['basic salar'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
data['basic salar'].plot.box(figsize=(5,5))
# Out:
# <Axes: >

# %%
data['basic salar'].plot.pie(figsize=(5,5), autopct='%.1f%%')
# Out:
# <Axes: ylabel='basic salar'>

# %%
data['basic salar'].plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
data['total salary']= data['basic salar']-data['fine']+ \
    (data['hr..a']*data['basic salar'])+\
        (data['d.a']*data['basic salar'])+\
            (data['t.a']*data['basic salar'])

# %%
data[['total salary','basic salar']].plot.bar(color=['#ff5555','green'])
# Out:
# <Axes: xlabel='id'>
