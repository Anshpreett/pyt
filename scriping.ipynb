# %%
from dputils.scrape import Tag, Scraper

# %%
url = "https://timesofindia.indiatimes.com/news"
news_scraper= Scraper(url)

# %%
Tag?
# Out:
# Init signature:
# Tag(
#     name: str = 'div',
#     output: str = 'text',
#     cls: str = None,
#     id: str = None,
#     attrs: dict = None,
# ) -> None
# Docstring:      Tag(name: str = 'div', output: str = 'text', cls: str = None, id: str = None, attrs: dict = None)
# File:           c:\users\lenovo\miniconda3\lib\site-packages\dputils\scrape.py
# Type:           type
# Subclasses:

# %%
Scraper?
# Out:
# Init signature:
# Scraper(
#     url: str,
#     user_agent: str = None,
#     cookies: dict = None,
#     clean: bool = False,
# )
# Docstring:      <no docstring>
# Init docstring:
# Initializes Scraper class
# Args:
#     url: url of the webpage
#     user_agent: user agent of the browser (Default value = None)
#     cookies: cookies of the browser (Default value = None)
#     clean: cleans url (Default value = True)
# File:           c:\users\lenovo\miniconda3\lib\site-packages\dputils\scrape.py
# Type:           type
# Subclasses:

# %%
target = Tag(cls = 'listing4')
items=Tag('li')
title=Tag('span',cls='w_tle')
desc=Tag('span',cls='w_desc')

# %%
news_scraper.get_all(target,items,heading=title,desc=desc)
# Out:
# [{'heading': 'All interfaith marriages in Uttarakhand since 2018 under police scanner',
#   'desc': 'Uttarakhand police, perhaps in the first such move by a state police department, have decided to examine all the interfaith marriages in the state in the past five years for any possible violation of the Uttarakhand Freedom of Religion Act (Amendment) 2022. The exercise would include all such marriages which took place after the implementation of the Act in 2018, highly- placed sources told TOI.'},
#  {'heading': 'Live: No lives lost after Biparjoy landfall in Gujarat',
#   'desc': ''},
#  {'heading': 'Why India has no problem being biggest buyer of Russian arms',
#   'desc': 'The German defence minister recently said that the extent of arms that India gets from Russia is not in his country’s interest. He’s not the only western power to think so. Here’s what is at stake for other arms manufacturing nations'},
#  {'heading': 'How Mumbai man lost Rs 1cr to cyber crooks after selling flat',
#   'desc': ''},
#  {'heading': 'In pics: Stone-pelting and arson keep Manipur on boil',
#   'desc': 'Arson in the heart of Imphal, the Manipur capital, and stone-pelting at security forces by residents bristling over the nine killings in a village of neighbouring Kangpokpi district two nights ago kept the state on the edge Thursday\u200b'},
#  {'heading': "US politicians 'looking forward' to PM Modi's visit",
#   'desc': 'With Prime Minister Narendra Modi ready to embark on his first state visit to US next week, a number of American politicians, prominent citizens as well as noted personalities from the diaspora are looking forward to according a grand welcome to the Indian leader.Twitter is already abuzz in anticipation of the high-profile visit, with prominent personalities posting video messages to welcome Prime Minister Modi, who will be in US from June 21 to 24.'},
#  {'heading': 'How chatbots are helping doctors become compassionate',
#   'desc': 'Despite the drawbacks of turning to artificial intelligence in medicine, some physicians find that ChatGPT improves their ability to communicate empathetically with patients'},
#  {'heading': '1st Ashes Test Live: Lyon removes Pope to give England second blow',
#   'desc': ''},
#  {'heading': 'Amazon Prime Lite: Nine things that subscribers get in this new plan',
#   'desc': ''},
#  {'heading': '3 kids picked as Puri temple servitors, to get Rs 1-2L a year',
#   'desc': 'Baladeb Dasmohapatra and Ekanshu Dasmohapatra are close to a year old only but will offer priestly service at the famous Jagannath Temple in Puri, and become eligible to receive a one-time annual remuneration ranging between Rs 1 lakh and Rs 2 lakh. According to tradition, 10-month-old Baladeb, one-year-old Ekanshu and another kid of same age were officially enlisted as servitors of the temple on Wednesday.'},
#  {'heading': 'Mercedes is looking to put ChatGPT in some of its cars',
#   'desc': ''},
#  {'heading': "Oliver, 12-year-old, claims 'double hat-trick' in one over",
#   'desc': "It is indeed a rare occurrence for a bowler to achieve a hat-trick in any form of cricket, but the achievement becomes even more extraordinary when a player manages to secure a 'double hat-trick'.  In a remarkable display of skill and precision, 12-year-old junior player Oliver Whitehouse accomplished this feat during a match for his club, Bromsgrove Cricket Club, vs Cookhill earlier this month."},
#  {'heading': 'Missed calls, WhatsApp, SMS and other ways to check SBI account bank balance',
#   'desc': ''},
#  {'heading': 'Debina Bonnerjee and Gurmeet Choudhary share experience on kids',
#   'desc': "Debina Bonnerjee and Gurmeet Choudhary are set to send their elder daughter Lianna to playschool. The duo was already late for the first Parents' meet at the school and shared how they thought they would get scolded on the first day itself for not being punctual. Talking about sending Lianna to school, Debina and Gurmeet shared their concerns and change in parenting patterns. \u200b"},
#  {'heading': 'Jennifer Garner opens up about ‘mess of parenting’',
#   'desc': 'Jennifer Garner and Ben Affleck split up after 10 years of marriage. As per reports, they maintain a healthy relationship as they co-parent their three kids. Ben married Jennifer Lopez last year, who is also a mom of two. Here is how the trio co-parent the 5 kids together.'},
#  {'heading': 'In pics: Cyclone Biparjoy leaves trail of destruction in Gujarat',
#   'desc': 'Cyclone Biparjoy, which ripped through Kutch and parts of Saurashtra region of Gujarat, has left a trail of destruction as gusty winds and rains wreaked havoc, officials said. '},
#  {'heading': 'Why Jabalpur is at epicentre of Madhya Pradesh politics',
#   'desc': 'Jabalpur has become the sought-after city for the ruling BJP and main opposition Congress ahead of the Madhya Pradesh assembly election which is likely to be held in November-December. Both the parties chose to launch their pre-election programmes from the city, which is called ‘Sanskaar-dhaani’ (cultural capital) of the state.'},
#  {'heading': 'ED arrests Ajay Parmar, nephew of ex-CBI judge Sudhir Parmar',
#   'desc': 'The Enforcement Directorate on Friday arrested Ajay Parmar, nephew of under-suspension former CBI judge Sudhir Parmar in a case linked that the Haryana Anti-Corruption Bureau is handling.'},
#  {'heading': 'Ex-TN DGP gets 3yrs in jail for sexually harassing IPS officer',
#   'desc': 'Suspended DGP of Tamil Nadu, Rajesh Das, was on Friday sentenced to three years in jail in a sexual harassment case. A serving woman IPS officer of superintendent of police rank had lodged a complaint against the DGP in 2021.'},
#  {'heading': 'Lunch habits that increase your risk for life-threatening diseases\u200b',
#   'desc': '\u200bThere are several factors that determine our health and one of these is good eating habits. On one hand, we are extremely careful about diet but unfortunately, on the other hand, we do not take care of our eating habits. These habits increase our risk of life-threatening diseases at a slower pace. Be it at home or at the workplace, here are a few eating habits you should correct immediately.\u200b'},
#  {'heading': None, 'desc': None},
#  {'heading': None, 'desc': None},
#  {'heading': None, 'desc': None}]

# %%
res=news_scraper.get_all(target,items,heading=title,desc=desc)

# %%
import pandas as pd

# %%
df=pd.DataFrame(res)
df
# Out:
#                                               heading  \
# 0   All interfaith marriages in Uttarakhand since ...
# 1   Live: No lives lost after Biparjoy landfall in...
# 2   Why India has no problem being biggest buyer o...
# 3   How Mumbai man lost Rs 1cr to cyber crooks aft...
# 4   In pics: Stone-pelting and arson keep Manipur ...
# 5   US politicians 'looking forward' to PM Modi's ...
# 6   How chatbots are helping doctors become compas...
# 7   1st Ashes Test Live: Lyon removes Pope to give...
# 8   Amazon Prime Lite: Nine things that subscriber...
# 9   3 kids picked as Puri temple servitors, to get...
# 10  Mercedes is looking to put ChatGPT in some of ...
# 11  Oliver, 12-year-old, claims 'double hat-trick'...
# 12  Missed calls, WhatsApp, SMS and other ways to ...
# 13  Debina Bonnerjee and Gurmeet Choudhary share e...
# 14  Jennifer Garner opens up about ‘mess of parent...
# 15  In pics: Cyclone Biparjoy leaves trail of dest...
# 16  Why Jabalpur is at epicentre of Madhya Pradesh...
# 17  ED arrests Ajay Parmar, nephew of ex-CBI judge...
# 18  Ex-TN DGP gets 3yrs in jail for sexually haras...
# 19  Lunch habits that increase your risk for life-...
# 20                                               None
# 21                                               None
# 22                                               None
#
#                                                  desc
# 0   Uttarakhand police, perhaps in the first such ...
# 1
# 2   The German defence minister recently said that...
# 3
# 4   Arson in the heart of Imphal, the Manipur capi...
# 5   With Prime Minister Narendra Modi ready to emb...
# 6   Despite the drawbacks of turning to artificial...
# 7
# 8
# 9   Baladeb Dasmohapatra and Ekanshu Dasmohapatra ...
# 10
# 11  It is indeed a rare occurrence for a bowler to...
# 12
# 13  Debina Bonnerjee and Gurmeet Choudhary are set...
# 14  Jennifer Garner and Ben Affleck split up after...
# 15  Cyclone Biparjoy, which ripped through Kutch a...
# 16  Jabalpur has become the sought-after city for ...
# 17  The Enforcement Directorate on Friday arrested...
# 18  Suspended DGP of Tamil Nadu, Rajesh Das, was o...
# 19  ​There are several factors that determine our ...
# 20                                               None
# 21                                               None
# 22                                               None

# %%
url="https://www.amazon.in/s?k=laptop&sprefix=la%2Caps%2C288&ref=nb_sb_ss_ts-doa-p_1_2"

# %%
amazon_scraper = Scraper(url)

# %%
target = Tag(cls = 's-main-slot s-result-list s-search-results sg-row')
items=Tag(cls='s-result-item')
title=Tag('h2',cls='a-size-mini a-spacing-none a-color-base s-line-clamp-2')
price=Tag('span',cls='a-price')

# %%
amazon_scraper.get_all(target, items, heading=title, price=price)
# Out:
# [{'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': 'Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 14" (35.56cm) FHD Thin & Light Laptop (8GB/512GB SSD/Windows 11/Office 2021/2Yr Warranty/3months Game Pass/Arctic Grey/1.41Kg), 82H701DNIN  ',
#   'price': '₹37,490₹37,490'},
#  {'heading': 'Acer Nitro 5 AN515-58 Gaming Laptop | 12th Gen Intel Core i7-12650H| NVIDIA GeForce RTX 3070Ti 8GB Laptop Graphics| 15.6" QHD 165Hz 3ms IPS Display | 16GB DDR4 | 1TB SSD | Killer WiFi 6 | RGB Keyboard  ',
#   'price': '₹1,09,990₹1,09,990'},
#  {'heading': 'Lenovo V15 Intel Celeron N4500 15.6" (39.62 cm) FHD (1920x1080) Antiglare 250 Nits Thin and Light Laptop (8GB RAM/256GB SSD/Windows 11 Home/Black/1Y Onsite/1.7 kg), 82QYA00MIN  ',
#   'price': '₹23,319₹23,319'},
#  {'heading': 'HP Laptop 15s, Intel Celeron N4500, 15.6 inch(39.6cm) HD Laptop (8GB RAM,512GB SSD,Intel UHD Graphics,Dual Speakers,Numeric Keypad,Alexa,Win 11,MSO 21,Natural Silver,1.69 Kgs) 15s-fq3071TU  ',
#   'price': '₹29,990₹29,990'},
#  {'heading': 'HP 247 G8 Laptop (AMD Athlon P-3045B HD/ 14 inches(35.5cm) HD /8GB RAM DDR4 /1TB HDD/Windows 11 Home/ W11 SL) One Year Warranty, Black, 67U77PA  ',
#   'price': '₹23,390₹23,390'},
#  {'heading': None, 'price': None},
#  {'heading': 'Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11th Gen 15.6" (39.62cm) FHD Laptop (8GB/256GB SSD/Win 11/Office 2021/2 Year Warranty/3 Month Game Pass/Arctic Grey/1.65Kg), 82H803GTIN  ',
#   'price': '₹35,990₹35,990'},
#  {'heading': '(Renewed) HP Chromebook 13 G1 6th Gen Intel Core m5 FHD Thin & Light Laptop (8 GB RAM/32 GB eMMC Storage/13.3" (33.8 cm) FHD/Chrome OS/WiFi/Bluetooth/Webcam/Intel Graphics)  ',
#   'price': '₹14,899₹14,899'},
#  {'heading': 'ASUS TUF Gaming A15, 15.6-inch (39.62 cms) FHD 144Hz, AMD Ryzen 5 4600H, 4GB NVIDIA GeForce GTX 1650, Gaming Laptop (8GB/512GB SSD/Windows 11/Black/2.3 Kg), FA506IHRZ-HN111W  ',
#   'price': '₹49,990₹49,990'},
#  {'heading': 'HP 15s,11th Gen Intel Core i3-1115G4 8GB RAM/512GB SSD 15.6-inch(39.6 cm) Micro-Edge Anti-Glare FHD Laptop/Alexa Built-in/Win 11/Intel UHD Graphics/Dual Speakers/MS Office 2021/1.69 Kg, 15s-fq2673TU  ',
#   'price': '₹39,990₹39,990'},
#  {'heading': 'Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 14" (35.56cm) FHD Thin & Light Laptop (8GB/512GB SSD/Windows 11/Office 2021/2Yr Warranty/3months Game Pass/Arctic Grey/1.41Kg), 82H701DNIN  ',
#   'price': '₹37,490₹37,490'},
#  {'heading': 'Apple 2023 MacBook Pro Laptop M2 Pro chip with 12‑core CPU and 19‑core GPU: 33.74 cm (14.2-inch), 16GB Unified Memory, 1TB SSD Storage. Works with iPhone/iPad; Silver  ',
#   'price': '₹2,29,990₹2,29,990'},
#  {'heading': 'Apple 2023 MacBook Pro Laptop M2 Pro chip with 12‑core CPU and 19‑core GPU: 33.74 cm (16.2-inch), 16GB Unified Memory, 1TB SSD Storage. Works with iPhone/iPad; Silver  ',
#   'price': '₹2,48,490₹2,48,490'},
#  {'heading': 'HP Laptop 15s, 12th Gen Intel Core i7-1255U, 15.6 inch(39.6cm)FHD Laptop(16GB RAM,512GB SSD,Intel Iris Xe Graphics,Dual Speakers,Alexa,Numeric Keypad,Win 11,MSO 21 1.69 Kgs,Natural Silver)15s-fq5190TU  ',
#   'price': '₹69,990₹69,990'},
#  {'heading': 'HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM/256GB SSD 14-inch(35.6 cm) Micro-Edge, Anti-Glare, FHD Laptop/Alexa Built-in/Win 11/Intel UHD Graphics/Dual Speakers/MSO 2021/1.41 Kg, 14s-dy2507TU  ',
#   'price': '₹36,490₹36,490'},
#  {'heading': 'HP 14s, AMD Ryzen 5-5500U 14 inches(35cm) FHD, IPS, Micro-Edge Display Laptop (8GB RAM/512GB SSD/Radeon Graphics/Windows 11/Alexa/Backlit Keyboard/MS Office/1.46kg, 14s-fq1092au)  ',
#   'price': '₹45,990₹45,990'},
#  {'heading': 'Lenovo V14-IGL Laptop Intel Celeron N4020/4GB DDR4 RAM/256GB SSD/DOS/14.0 HD/Intel UHD Graphics 600/1 Year Warranty  ',
#   'price': '₹19,999₹19,999'},
#  {'heading': 'AXL Laptop (Vayu Book) Newly Launched Thin & Light | 14.1 Inch HD Display (4GB/128GB SSD | 1920 * 1080 FHD IPS | HD Gemini Lake N4020 | Windows 11 Home | UHD Graphics 600 | Space Grey  ',
#   'price': '₹16,990₹16,990'},
#  {'heading': 'ASUS Vivobook 16X, AMD Ryzen 7 5800H, 16" (40.64 cm) WUXGA, Thin & Light Laptop (16GB/512GB SSD/Integrated Graphics/Windows 11/Office 2021/Backlit/Fingerprint/Silver/1.88 kg), M1603QA-MB742WS  ',
#   'price': '₹58,990₹58,990'},
#  {'heading': 'Lenovo Ideapad 3 AMD Ryzen 5 5500U 15.6" (39.62cm) FHD Thin & Light Laptop (8GB/512GB SSD/Windows 11/Office 2021/Backlit Keyboard/2Yr Warranty/Arctic Grey/1.65Kg), 82KU017KIN  ',
#   'price': '₹43,975₹43,975'},
#  {'heading': 'Apple 2020 MacBook Air Laptop M1 chip, 13.3-inch/33.74 cm Retina Display, 8GB RAM, 256GB SSD Storage, Backlit Keyboard, FaceTime HD Camera, Touch ID. Works with iPhone/iPad; Gold  ',
#   'price': '₹81,990₹81,990'},
#  {'heading': 'Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen 15.6" (39.62cm) FHD Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/2Yr Warranty/3months Game Pass/Arctic Grey/1.63Kg), 82RK0085IN  ',
#   'price': '₹58,149₹58,149'},
#  {'heading': 'Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 15.6" (39.62cm) FHD IPS Thin & Light Laptop (16GB/512GB SSD/Windows 11/Office 2021/Backlit/FPR/3months Game Pass/Storm Grey/1.85Kg), 82SF008WIN  ',
#   'price': '₹79,990₹79,990'},
#  {'heading': 'Crucial BX500 240GB 3D NAND SATA 6.35 cm (2.5-inch) SSD (CT240BX500SSD1)  ',
#   'price': '₹1,407₹1,407'},
#  {'heading': 'Crucial BX500 240GB 3D NAND SATA 6.35 cm (2.5-inch) SSD (CT240BX500SSD1)  ',
#   'price': '₹1,407₹1,407'},
#  {'heading': 'Crucial BX500 500GB 2.5-inch SATA 3D NAND Internal SSD Upto 550 MB/s  ',
#   'price': '₹2,309₹2,309'},
#  {'heading': 'Western Digital WD Green SATA 240GB, Up to 545MB/s, 2.5 Inch/7 mm, 3Y Warranty, Internal Solid State Drive (SSD) (WDS240G3G0A)  ',
#   'price': '₹1,179₹1,179'},
#  {'heading': 'SanDisk 1TB Extreme Portable SSD 1050MB/s R, 1000MB/s W,Upto 2 Meter Drop Protection with IP55 Water/dust Resistance, HW Encryption, PC,MAC & TypeC Smartphone Compatible, 5Y Warranty, External SSD  ',
#   'price': '₹8,999₹8,999'},
#  {'heading': 'Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11th Gen 15.6" (39.62cm) FHD Laptop (8GB/256GB SSD/Win 11/Office 2021/2 Year Warranty/3 Month Game Pass/Arctic Grey/1.65Kg), 82H803GTIN  ',
#   'price': '₹35,990₹35,990'},
#  {'heading': 'ASUS TUF Gaming A15, 15.6-inch (39.62 cms) FHD 144Hz, AMD Ryzen 5 4600H, 4GB NVIDIA GeForce GTX 1650, Gaming Laptop (8GB/512GB SSD/Windows 11/Black/2.3 Kg), FA506IHRZ-HN111W  ',
#   'price': '₹49,990₹49,990'},
#  {'heading': 'HP 15s,11th Gen Intel Core i3-1115G4 8GB RAM/512GB SSD 15.6-inch(39.6 cm) Micro-Edge Anti-Glare FHD Laptop/Alexa Built-in/Win 11/Intel UHD Graphics/Dual Speakers/MS Office 2021/1.69 Kg, 15s-fq2673TU  ',
#   'price': '₹39,990₹39,990'},
#  {'heading': 'HP 15s, Ryzen 5-5500U, 16GB RAM/512GB SSD 15.6-inches(39.6 cm) FHD, Micro-Edge, Anti-Glare Laptop/Alexa Built-in/Windows 11 /AMD Radeon Graphics/Dual Speakers/MS Office 2021/1.69 Kg, 15s-eq2182AU  ',
#   'price': '₹49,990₹49,990'},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None}]

# %%
result=amazon_scraper.get_all(target, items, heading=title, price=price)

# %%
df=pd.DataFrame(result)
df
# Out:
#                                               heading               price
# 0                                                None                None
# 1                                                None                None
# 2   Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 1...      ₹37,490₹37,490
# 3   Acer Nitro 5 AN515-58 Gaming Laptop | 12th Gen...  ₹1,09,990₹1,09,990
# 4   Lenovo V15 Intel Celeron N4500 15.6" (39.62 cm...      ₹23,319₹23,319
# 5   HP Laptop 15s, Intel Celeron N4500, 15.6 inch(...      ₹29,990₹29,990
# 6   HP 247 G8 Laptop (AMD Athlon P-3045B HD/ 14 in...      ₹23,390₹23,390
# 7                                                None                None
# 8   Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...      ₹35,990₹35,990
# 9   (Renewed) HP Chromebook 13 G1 6th Gen Intel Co...      ₹14,899₹14,899
# 10  ASUS TUF Gaming A15, 15.6-inch (39.62 cms) FHD...      ₹49,990₹49,990
# 11  HP 15s,11th Gen Intel Core i3-1115G4 8GB RAM/5...      ₹39,990₹39,990
# 12  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 1...      ₹37,490₹37,490
# 13  Apple 2023 MacBook Pro Laptop M2 Pro chip with...  ₹2,29,990₹2,29,990
# 14  Apple 2023 MacBook Pro Laptop M2 Pro chip with...  ₹2,48,490₹2,48,490
# 15  HP Laptop 15s, 12th Gen Intel Core i7-1255U, 1...      ₹69,990₹69,990
# 16  HP 14s, 11th Gen Intel Core i3-1115G4, 8GB RAM...      ₹36,490₹36,490
# 17  HP 14s, AMD Ryzen 5-5500U 14 inches(35cm) FHD,...      ₹45,990₹45,990
# 18  Lenovo V14-IGL Laptop Intel Celeron N4020/4GB ...      ₹19,999₹19,999
# 19  AXL Laptop (Vayu Book) Newly Launched Thin & L...      ₹16,990₹16,990
# 20  ASUS Vivobook 16X, AMD Ryzen 7 5800H, 16" (40....      ₹58,990₹58,990
# 21  Lenovo Ideapad 3 AMD Ryzen 5 5500U 15.6" (39.6...      ₹43,975₹43,975
# 22  Apple 2020 MacBook Air Laptop M1 chip, 13.3-in...      ₹81,990₹81,990
# 23  Lenovo IdeaPad Slim 3 Intel Core i5 12th Gen 1...      ₹58,149₹58,149
# 24  Lenovo IdeaPad Slim 5 Intel Core i7 12th Gen 1...      ₹79,990₹79,990
# 25  Crucial BX500 240GB 3D NAND SATA 6.35 cm (2.5-...        ₹1,407₹1,407
# 26  Crucial BX500 240GB 3D NAND SATA 6.35 cm (2.5-...        ₹1,407₹1,407
# 27  Crucial BX500 500GB 2.5-inch SATA 3D NAND Inte...        ₹2,309₹2,309
# 28  Western Digital WD Green SATA 240GB, Up to 545...        ₹1,179₹1,179
# 29  SanDisk 1TB Extreme Portable SSD 1050MB/s R, 1...        ₹8,999₹8,999
# 30  Lenovo IdeaPad Slim 3 Intel Core i3-1115G4 11t...      ₹35,990₹35,990
# 31  ASUS TUF Gaming A15, 15.6-inch (39.62 cms) FHD...      ₹49,990₹49,990
# 32  HP 15s,11th Gen Intel Core i3-1115G4 8GB RAM/5...      ₹39,990₹39,990
# 33  HP 15s, Ryzen 5-5500U, 16GB RAM/512GB SSD 15.6...      ₹49,990₹49,990
# 34                                               None                None
# 35                                               None                None
# 36                                               None                None
# 37                                               None                None

# %% [markdown]
# # EX3

# %%
url="https://www.amazon.in/s?k=handbags&sprefix=handb%2Caps%2C748&ref=nb_sb_ss_ts-doa-p_2_5"

# %%
amazonscraper = Scraper(url)

# %%
target = Tag(cls ='s-main-slot s-result-list s-search-results sg-row')
items=Tag(cls='sg-col-inner')
title=Tag('h2',cls='a-size-mini s-line-clamp-1')
price=Tag('span',cls='a-price')

# %%
amazonscraper.get_all(target, items, heading=title, price=price)
# Out:
# [{'heading': 'Fastrack', 'price': '₹1,897₹1,897'},
#  {'heading': 'Accessorize London', 'price': '₹1,299₹1,299'},
#  {'heading': 'Berliner Bags', 'price': '₹7,999₹7,999'},
#  {'heading': 'Accessorize London', 'price': '₹1,599₹1,599'},
#  {'heading': 'INOVERA (LABEL)', 'price': '₹1,299₹1,299'},
#  {'heading': 'Carrylux', 'price': '₹549₹549'},
#  {'heading': 'Lavie', 'price': '₹1,119₹1,119'},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': 'Lino Perros', 'price': '₹1,303₹1,303'},
#  {'heading': 'creeper', 'price': '₹459₹459'},
#  {'heading': 'Lavie', 'price': '₹1,179₹1,179'},
#  {'heading': 'The Purple Tree', 'price': '₹649₹649'},
#  {'heading': 'Caprese', 'price': '₹649₹649'},
#  {'heading': 'Lavie', 'price': '₹1,099₹1,099'},
#  {'heading': 'Envias', 'price': '₹449₹449'},
#  {'heading': 'Amazon Brand - Symbol', 'price': '₹789₹789'},
#  {'heading': None, 'price': None},
#  {'heading': 'Amazon Brand - Symbol', 'price': '₹789₹789'},
#  {'heading': 'Amazon Brand - Eden & Ivy', 'price': '₹649₹649'},
#  {'heading': 'Amazon Brand - Eden & Ivy', 'price': '₹629₹629'},
#  {'heading': 'Amazon Brand - Eden & Ivy', 'price': '₹590.01₹590.01'},
#  {'heading': 'Amazon Brand - Eden & Ivy', 'price': '₹729₹729'},
#  {'heading': 'Amazon Brand - Eden & Ivy', 'price': '₹609₹609'},
#  {'heading': 'Amazon Brand - Eden & Ivy', 'price': '₹569₹569'},
#  {'heading': 'Camdeez', 'price': '₹5,067₹5,067'},
#  {'heading': None, 'price': None},
#  {'heading': 'Camdeez', 'price': '₹5,067₹5,067'},
#  {'heading': 'patu', 'price': '₹1,575₹1,575'},
#  {'heading': 'Okayji', 'price': '₹219₹219'},
#  {'heading': 'Relavel', 'price': '₹3,487₹3,487'},
#  {'heading': 'Conair', 'price': '₹3,945₹3,945'},
#  {'heading': 'PHOGARY', 'price': '₹1,531.54₹1,531.54'},
#  {'heading': 'APREUTY', 'price': '₹3,176₹3,176'},
#  {'heading': 'Relavel', 'price': '₹2,496₹2,496'},
#  {'heading': 'EXOTIC', 'price': '₹1,329₹1,329'},
#  {'heading': 'EXOTIC', 'price': '₹1,195₹1,195'},
#  {'heading': 'creeper', 'price': '₹436₹436'},
#  {'heading': 'Fargo', 'price': '₹497₹497'},
#  {'heading': 'SXF SPEED X FASHION', 'price': '₹640₹640'},
#  {'heading': 'Lino Perros', 'price': '₹1,078₹1,078'},
#  {'heading': 'Lyrovo', 'price': '₹999₹999'},
#  {'heading': 'LAPIS O LUPO', 'price': '₹899₹899'},
#  {'heading': 'LAPIS O LUPO', 'price': '₹650₹650'},
#  {'heading': 'LAPIS O LUPO', 'price': '₹1,208₹1,208'},
#  {'heading': 'Bagsworks', 'price': '₹722₹722'},
#  {'heading': 'Nelle Harper', 'price': '₹699₹699'},
#  {'heading': 'Fargo', 'price': '₹409₹409'},
#  {'heading': 'Speed X Fashion', 'price': '₹1,087₹1,087'},
#  {'heading': 'Lino Perros', 'price': '₹1,348₹1,348'},
#  {'heading': 'Shining Star', 'price': '₹999₹999'},
#  {'heading': 'WILD MODA', 'price': '₹849₹849'},
#  {'heading': 'WOMEN MARKS', 'price': '₹987₹987'},
#  {'heading': 'Fantosy', 'price': '₹499₹499'},
#  {'heading': 'WOMEN MARKS', 'price': '₹500₹500'},
#  {'heading': 'WOMEN MARKS', 'price': '₹663₹663'},
#  {'heading': 'MARK & KEITH', 'price': '₹899₹899'},
#  {'heading': 'Lino Perros', 'price': '₹599₹599'},
#  {'heading': 'Lavie', 'price': '₹1,129₹1,129'},
#  {'heading': 'DANIEL CLARK', 'price': '₹525₹525'},
#  {'heading': 'ENOKI', 'price': '₹363.93₹363.93'},
#  {'heading': 'Fostelo', 'price': '₹620₹620'},
#  {'heading': 'Lavie', 'price': '₹1,507₹1,507'},
#  {'heading': 'Nelle Harper', 'price': '₹699₹699'},
#  {'heading': 'The Clownfish', 'price': '₹999₹999'},
#  {'heading': 'Aliza', 'price': '₹416₹416'},
#  {'heading': 'addixon', 'price': '₹699₹699'},
#  {'heading': 'DANIEL CLARK', 'price': '₹489₹489'},
#  {'heading': 'Lavie', 'price': '₹1,238.49₹1,238.49'},
#  {'heading': 'Fantosy', 'price': '₹499₹499'},
#  {'heading': 'WOMEN MARKS', 'price': '₹995₹995'},
#  {'heading': 'LEGAL BRIBE', 'price': '₹1,117₹1,117'},
#  {'heading': 'Caprese', 'price': '₹649₹649'},
#  {'heading': 'Lino Perros', 'price': '₹1,138₹1,138'},
#  {'heading': 'Bagsworks', 'price': '₹549₹549'},
#  {'heading': 'Lekhraj Handicraft', 'price': '₹499₹499'},
#  {'heading': 'Belladona', 'price': '₹339₹339'},
#  {'heading': 'LEGAL BRIBE', 'price': '₹1,190₹1,190'},
#  {'heading': 'Haute Sauce', 'price': '₹989₹989'},
#  {'heading': 'STEEZE', 'price': '₹751₹751'},
#  {'heading': 'The Purple Tree', 'price': '₹649₹649'},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None},
#  {'heading': None, 'price': None}]

# %%
result=amazonscraper.get_all(target, items, heading=title, price=price)

# %%
df=pd.DataFrame(result)
df
# Out:
#                heading         price
# 0             Fastrack  ₹1,897₹1,897
# 1   Accessorize London  ₹1,299₹1,299
# 2        Berliner Bags  ₹7,999₹7,999
# 3   Accessorize London  ₹1,599₹1,599
# 4      INOVERA (LABEL)  ₹1,299₹1,299
# ..                 ...           ...
# 95                None          None
# 96                None          None
# 97                None          None
# 98                None          None
# 99                None          None
#
# [100 rows x 2 columns]
